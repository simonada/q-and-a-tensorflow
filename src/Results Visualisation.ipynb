# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.plotly as py
import matplotlib.patches as mpatches

# %%
# data to plot
n_groups = 3
f, (ax1, ax2, ax3) = plt.subplots(3, sharey=True, figsize=(6, 10))

 
# plot 1   
metric_accuracy_sso= (0.88, 0.85, 0.85)
metric_accuracy_all_sent= (0.68, 0.74, 0.49)

index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = ax1.bar(index, metric_accuracy_sso, bar_width,
                 alpha=opacity,
                 color='orange',
                 label='Supporting only')
 
rects2 = ax1.bar(index + bar_width, metric_accuracy_all_sent, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Full context')
 
ax1.set_xlabel('Task 5: Three argument relations')
ax1.set_ylabel('Accuracy')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(('Low-level API', 'tf.keras', 'Eager Execuction'))
handles1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(handles1, labels1)

# plot 2
metric_accuracy_sso= (0.60, 0.52, 0.47)
metric_accuracy_all_sent= (0.53, 0.50, 0.49)

rects3 = ax2.bar(index, metric_accuracy_sso, bar_width,
                 alpha=opacity,
                 color='orange',
                 label='Supporting only')
 
rects4 = ax2.bar(index + bar_width, metric_accuracy_all_sent, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Full context')
 
ax2.set_xlabel('Task 6: Yes/No questions')
ax2.set_ylabel('Accuracy')
ax2.set_xticks(index + bar_width)
ax2.set_xticklabels(('Low-level API', 'tf.keras', 'Eager Execution'))
handles2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(handles2, labels2)

# plot 3
metric_accuracy_sso= (0.71, 0.54, 0.50)
metric_accuracy_all_sent= (0.49, 0.45, 0.49)

rects5 = ax3.bar(index, metric_accuracy_sso, bar_width,
                 alpha=opacity,
                 color='orange',
                 label='Supporting only')
 
rects6 = ax3.bar(index + bar_width, metric_accuracy_all_sent, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Full context')
 
ax3.set_xlabel('Task 10: Indefinite knowledge')
ax3.set_ylabel('Accuracy')
ax3.set_xticks(index + bar_width)
ax3.set_xticklabels(('Low-level API', 'tf.keras', 'Eager Execution'))
handles3, labels3 = ax3.get_legend_handles_labels()
ax3.legend(handles3, labels3)

plt.tight_layout()
plt.show()

# %%
# data to plot
n_groups = 3
f, (ax1, ax2, ax3) = plt.subplots(3, sharey=True, figsize=(6, 10))

 
# plot 1   
metric_accuracy_sso= (94.56, 36.48, 0.85)
metric_accuracy_all_sent= (704.18, 1235.81, 0.49)

index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = ax1.bar(index, metric_accuracy_sso, bar_width,
                 alpha=opacity,
                 color='pink',
                 label='Supporting only')
 
rects2 = ax1.bar(index + bar_width, metric_accuracy_all_sent, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Full context')
 
ax1.set_xlabel('Task 5: Three argument relations')
ax1.set_ylabel('Time (sec)')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(('Low-level API', 'tf.keras', 'Eager Execuction'))
handles1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(handles1, labels1)

# plot 2
metric_accuracy_sso= (98.11, 54.90, 0.47)
metric_accuracy_all_sent= (206.24, 281.92, 0.49)

rects3 = ax2.bar(index, metric_accuracy_sso, bar_width,
                 alpha=opacity,
                 color='pink',
                 label='Supporting only')
 
rects4 = ax2.bar(index + bar_width, metric_accuracy_all_sent, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Full context')
 
ax2.set_xlabel('Task 6: Yes/No questions')
ax2.set_ylabel('Time (sec)')
ax2.set_xticks(index + bar_width)
ax2.set_xticklabels(('Low-level API', 'tf.keras', 'Eager Execution'))
handles2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(handles2, labels2)

# plot 3
metric_accuracy_sso= (96.22, 39.55, 0.50)
metric_accuracy_all_sent= (201.05, 174.48, 0.49)

rects5 = ax3.bar(index, metric_accuracy_sso, bar_width,
                 alpha=opacity,
                 color='pink',
                 label='Supporting only')
 
rects6 = ax3.bar(index + bar_width, metric_accuracy_all_sent, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Full context')
 
ax3.set_xlabel('Task 10: Indefinite knowledge')
ax3.set_ylabel('Time (sec)')
ax3.set_xticks(index + bar_width)
ax3.set_xticklabels(('Low-level API', 'tf.keras', 'Eager Execution'))
handles3, labels3 = ax3.get_legend_handles_labels()
ax3.legend(handles3, labels3)

plt.tight_layout()
plt.show()
